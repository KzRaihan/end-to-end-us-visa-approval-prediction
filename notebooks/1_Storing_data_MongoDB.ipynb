# %% [markdown]
# ## Topic: Store the Local Data into MongoDB Atlas(cloud)

# %% [markdown]
# ### OUTCOMES
#
# - 1. Load the Dataset from local environment
#
# - 2. Some Basic Operation
#
# - 3. Load the Dataset into MongoDB Atlas (cloud)

# %% [markdown]
# ### 1. Load the Dataset from local environment

# %%
print("okay")
# Out:
# okay

# %%
# import library
import pandas as pd

# %%
# show the Present working directory
# %pwd
# Out:
# 'e:\\Data Science\\ALL Projects\\ML ALL Projects\\end-to-end-us-visa-approval-prediction\\notebooks'

# %% [markdown]
# - Key NOTE:
#     - First we go to the root directory
#
#     - then access the Shipment-data.csv,
#         - command: ../data/Shipment-data.csv
#             - where,
#                 - ../ means -> go the Root Directory

# %%
# load the dataset
data = pd.read_csv("../data/Visadataset.csv")

data.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# ### 2. Some Basic Operation

# %%
# Show first 5 rows
data.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
# show last 5 rows
data.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
# shape of the data
data.shape
# Out:
# (25480, 12)

# %% [markdown]
# - Short Note:
#     - Total number of rows = 25480
#     - Total number of columns = 12

# %%
# show the dtype and memory usage
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
# type of dataset
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Convert Pandas DataFrame to Dictionary
#
# - Because MongoDB store the data into json or dictionary format
#
# - orient = "records": Give the well structure

# %%
data_dic = data.to_dict(orient = "records")

# %%
# length
len(data_dic)
# Out:
# 25480

# %%
# Check type of data
type(data_dic)
# Out:
# list

# %% [markdown]
# ### 3. Load the Dataset into MongoDB Atlas (cloud)

# %%
# Database name
DB_NAME = "US_VISA_DB"
COLLECTION_NAME = "visa_applications"
CONNECTION_URL = "Enter your MongoDB connection URL here"

# %% [markdown]
# - short note:
#
#     - DB_NAME = Database name
#
#     - COLLECTION_NAME = Table name of the Database
#
#     - CONNECTION_URL = Connection string between MongoDB Atlas and python

# %% [markdown]
# ### Storing Data to MongoDB Database

# %%
# import library
import pymongo

# %%
# Step 1: Connect to the server  (e.g. MongoDB Atlas) with authentication.
client = pymongo.MongoClient(CONNECTION_URL)

# Step 2: Select the database
data_base = client[DB_NAME]

# Step 3: Select the collection
collection = data_base[COLLECTION_NAME]

# %%
# Inserts all training / feature / inference records  into MongoDB
rec = collection.insert_many(data_dic)

# %% [markdown]
# - Key NOTE:
#     - Upload our local Data to MangoDB atlas

# %% [markdown]
# ### Fetching Data from MongoDB Database

# %%
# Fetching all records
records = collection.find()

# %%
# it give us an object of the data and it can be iterable
records

# %%
# one one to display
# for i in records:
#     print(i)

# for i,j in enumerate(records):
#     print(f"Record {i}: {j}")

# %% [markdown]
# ### Convert records into DataFrame

# %%
# fetching all record from the MongoDB atlas and convert into dataframe
df = pd.DataFrame(list(collection.find()))

# %%
# show first 5 rows
df.head()
# Out:
#                         _id case_id      continent education_of_employee  \
# 0  6a6f916358ee79f667bf5e96  EZYV22  North America              Master's
# 1  6a6f916358ee79f667bf5e99  EZYV25         Europe             Doctorate
# 2  6a6f916358ee79f667bf5e9a  EZYV26  North America              Master's
# 3  6a6f916358ee79f667bf5ea6  EZYV38         Europe              Master's
# 4  6a6f916358ee79f667bf5eaf  EZYV47           Asia            Bachelor's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  Y                     N             1706         2013
# 1                  Y                     N              241         1981
# 2                  N                     N             1100         1997
# 3                  Y                     Y               44         1965
# 4                  Y                     N             2623         2008
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# ...

# %%
# Drop the _id columns
if "_id" in df.columns:
    df.drop(columns="_id", inplace=True)

# %% [markdown]
# - Key Note:
#     - Because, MongoDB Create a unique Id for each records.

# %%
df.head()
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV22  North America              Master's                  Y
# 1  EZYV25         Europe             Doctorate                  Y
# 2  EZYV26  North America              Master's                  N
# 3  EZYV38         Europe              Master's                  Y
# 4  EZYV47           Asia            Bachelor's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N             1706         2013              Midwest
# 1                     N              241         1981              Midwest
# 2                     N             1100         1997              Midwest
# 3                     Y               44         1965                South
# 4                     N             2623         2008                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# ...

# %% [markdown]
# #### Convert DataFrame to CSV format

# %%
# convert DataFrame -> CSV
df.to_csv("visa_dataset.csv", index = False)

# %% [markdown]
# ### Deleted the DataBase

# %%
# Deleted Database
# client.drop_database("KzRaihan")
