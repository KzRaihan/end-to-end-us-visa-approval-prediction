# %% [markdown]
# ## Topic: Data Drift Detection Demo using Evidently on BostonHousing Dataset

# %%
## import Require libraries

import pandas as pd
import numpy as np

from sklearn import datasets

from evidently.report import Report
from evidently.metric_preset import DataDriftPreset

# %%
# load the BostonHousing data from github
data_url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"

# %%
# convert to dataframe
boston_frame = pd.read_csv(data_url)

boston_frame.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# info
boston_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
# shape
boston_frame.shape
# Out:
# (506, 14)

# %%
# Training set 
reference_data = boston_frame.iloc[:200]

# testing set
current_data = boston_frame.iloc[200:]

# %%
reference_data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 195  0.01381  80.0   0.46     0  0.422  7.875  32.0  5.6484    4  255
# 196  0.04011  80.0   1.52     0  0.404  7.287  34.1  7.3090    2  329
# 197  0.04666  80.0   1.52     0  0.404  7.107  36.6  7.3090    2  329
# 198  0.03768  80.0   1.52     0  0.404  7.274  38.3  7.3090    2  329
# 199  0.03150  95.0   1.47     0  0.403  6.975  15.3  7.6534    3  402
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
data_drift_report = Report(
    metrics=[
        DataDriftPreset()
    ]
)

# %%
data_drift_report.run(
    reference_data=reference_data,
    current_data=current_data,
    column_mapping=None
)
# Save the report as HTML
data_drift_report.save_html("data_drift_report.html")

# %% [markdown]
# - Key Note:
#     - Here, save data drift report into html file format.

# %% [markdown]
# ### Save to json format

# %%
# import library
from evidently.model_profile import Profile
from evidently.profile_sections import DataDriftProfileSection
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 # import library
# ----> 2 from evidently.model_profile import Profile
#       3 from evidently.profile_sections import DataDriftProfileSection
#
# ModuleNotFoundError: No module named 'evidently.model_profile'

# %%
boston_data_drift_profile = Profile(sections=[DataDriftProfileSection()])
